# %%
# write.table(red.neuronal$weights[[1]][[1]],"clipboard", sep=",", row.names=FALSE)
# Comando para copiar desde el porta papel
"V1","V2"
11.1392260245541,5.63092946595401
0.574745449575871,-2.22172422958381
1.26544314680603,8.92677621325984
-2.73232077335164,-1.87541149838109
-2.83059023464991,-14.192277917949
# Out:
# (-2.83059023464991, -14.192277917949)

# %%
import math
import numpy as np
import seaborn as sns

# %%
W1 = np.array([[11.1392260245541,5.63092946595401],
                [0.574745449575871,-2.22172422958381],
                [1.26544314680603,8.92677621325984],
                [-2.73232077335164,-1.87541149838109],
                [-2.83059023464991,-14.192277917949]])

# %%
W2 = np.array([[0.811446207795352,-1.08515730768611,-143.743396829393],
                [0.222004536300692,-2.00394851123848,260.030315249046],
                [-2.67566693775562,4.22386268851247,-98.4913163306113]])

# %%
W3 = np.array([[1.20308096196451,-1.08100154537369,-0.135208073830395],
                [-1.72444633567608,1.61136469297143,1.28877716394054],
                [0.0210701855998521,-0.117571375864246,1.04605562532198],
                [0.0599685838907911,0.907893037961063,-0.865416251190173]])

# %%
def f_act(X):
    activada = np.array([1/(1 + math.exp(-x)) for x in X])
    return activada

# %%
# Carga de datos
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
xcols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
especie = iris['species'].unique()
especie
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
X = iris[xcols].copy()
X.insert(0, 'bias', 1)

# %%
X
# Out:
#      bias  sepal_length  sepal_width  petal_length  petal_width
# 0       1           5.1          3.5           1.4          0.2
# 1       1           4.9          3.0           1.4          0.2
# 2       1           4.7          3.2           1.3          0.2
# 3       1           4.6          3.1           1.5          0.2
# 4       1           5.0          3.6           1.4          0.2
# ..    ...           ...          ...           ...          ...
# 145     1           6.7          3.0           5.2          2.3
# 146     1           6.3          2.5           5.0          1.9
# 147     1           6.5          3.0           5.2          2.0
# 148     1           6.2          3.4           5.4          2.3
# 149     1           5.9          3.0           5.1          1.8
#
# [150 rows x 5 columns]

# %%
prediccion = []
for index, fila in X.iterrows():
    capa1 = f_act(fila.dot(W1))
    capa1 = np.insert(capa1, 0, 1)
    capa2 = f_act(capa1.dot(W2))
    capa2 = np.insert(capa2, 0, 1)
    salida = f_act(capa2.dot(W3))
    prediccion.append(especie[np.argmax(salida)])

# %%
iris['Prediccion'] = prediccion
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species Prediccion
# 0           5.1          3.5           1.4          0.2  setosa     setosa
# 1           4.9          3.0           1.4          0.2  setosa     setosa
# 2           4.7          3.2           1.3          0.2  setosa     setosa
# 3           4.6          3.1           1.5          0.2  setosa     setosa
# 4           5.0          3.6           1.4          0.2  setosa     setosa

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Prediccion
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...

# %%
iris.iloc[73:78] # para mandar indices, de donde a donde quiero ver la informacion
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 73           6.1          2.8           4.7          1.2  versicolor
# 74           6.4          2.9           4.3          1.3  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
# 77           6.7          3.0           5.0          1.7  versicolor
#
#     Prediccion
# 73  versicolor
# 74  versicolor
# 75  versicolor
# 76  versicolor
# 77  versicolor

# %%
errores = iris[iris['species'] != iris['prediccion']]
errores
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Program Files\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\Program Files\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Program Files\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prediccion'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
eficiencia = (1 - len(errores)/len(iris))*100
eficiencia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 eficiencia = (1 - len(errores)/len(iris))*100
#       2 eficiencia
#
# NameError: name 'errores' is not defined
